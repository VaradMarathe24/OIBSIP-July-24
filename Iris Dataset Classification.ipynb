# %% [markdown]
# Import the required libraries into the code.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# Loading the data

# %%
flower=pd.read_csv("Iris.csv")
print(flower)
print(flower.shape)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(flower.describe())
print(flower.isna().sum())
print(flower.describe())
print(flower.head())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# ...

# %%
flower.head(150)
flower.tail(100)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
n=len(flower[flower['Species']=='Iris-versicolor'])
print("The number of flowers of the Versicolor species in the Iris Dataset:",n)
# Out:
# The number of flowers of the Versicolor species in the Iris Dataset: 50

# %%
v=len(flower[flower['Species']=='Iris-virginica'])
print("The number of flowers of the Virginica species in the Iris Dataset:",v)
# Out:
# The number of flowers of the Virginica species in the Iris Dataset: 50

# %%
m=len(flower[flower['Species']=='Iris-setosa'])
print("The number of flowers of the Setosa species in the Iris Dataset:",m)
# Out:
# The number of flowers of the Setosa species in the Iris Dataset: 50

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(flower.drop('Species',axis=1),flower['Species'],test_size=0.2,random_state=0)
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
x_new=np.array([[5,2.9,1,0.2,2]])

# %%
prediction=knn.predict(x_new)
print("Prediction:{}".format(prediction))
# Out:
# Prediction:['Iris-setosa']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
#check accuracy of the model
from sklearn.svm import SVC
model1=SVC()
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)
from sklearn.metrics import accuracy_score
print('Accuracy=',accuracy_score(y_test,y_pred))
# Out:
# Accuracy= 1.0

# %%
import matplotlib.pyplot as plt

X=flower['SepalLengthCm'].values.reshape(-1,1)
print(X)
Y=flower['SepalWidthCm'].values.reshape(-1,1)
print(Y)
# Out:
# [[5.1]
#  [4.9]
#  [4.7]
#  [4.6]
#  [5. ]
#  [5.4]
#  [4.6]
#  [5. ]
#  [4.4]
#  [4.9]
#  [5.4]
#  [4.8]
#  [4.8]
#  [4.3]
#  [5.8]
#  [5.7]
#  [5.4]
#  [5.1]
#  [5.7]
#  [5.1]
#  [5.4]
#  [5.1]
#  [4.6]
#  [5.1]
#  [4.8]
#  [5. ]
#  [5. ]
#  [5.2]
#  [5.2]
#  [4.7]
#  [4.8]
#  [5.4]
#  [5.2]
#  [5.5]
#  [4.9]
#  [5. ]
#  [5.5]
#  [4.9]
#  [4.4]
#  [5.1]
#  [5. ]
#  [4.5]
#  [4.4]
#  [5. ]
#  [5.1]
#  [4.8]
#  [5.1]
#  [4.6]
#  [5.3]
#  [5. ]
#  [7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]
#  [5.7]
#  [6.3]
#  [4.9]
#  [6.6]
#  [5.2]
#  [5. ]
#  [5.9]
#  [6. ]
#  [6.1]
#  [5.6]
#  [6.7]
#  [5.6]
#  [5.8]
#  [6.2]
#  [5.6]
#  [5.9]
#  [6.1]
#  [6.3]
#  [6.1]
#  [6.4]
#  [6.6]
#  [6.8]
#  [6.7]
#  [6. ]
#  [5.7]
#  [5.5]
#  [5.5]
#  [5.8]
#  [6. ]
#  [5.4]
#  [6. ]
#  [6.7]
#  [6.3]
#  [5.6]
#  [5.5]
#  [5.5]
#  [6.1]
#  [5.8]
#  [5. ]
#  [5.6]
#  [5.7]
#  [5.7]
#  [6.2]
#  [5.1]
#  [5.7]
#  [6.3]
#  [5.8]
#  [7.1]
#  [6.3]
#  [6.5]
#  [7.6]
#  [4.9]
#  [7.3]
#  [6.7]
#  [7.2]
#  [6.5]
# ...

# %%
#plotting the graph
plt.title("Iris Dataset Classification")
plt.xlabel("Length of the sepal (in cm)",size=15)
plt.ylabel("Width of the sepal(in cm)",size=15)
plt.scatter(X,Y,c='b',s=20)
plt.show()

# %%
fig=plt.figure()
plt.figure(1)
plt.boxplot([flower['SepalLengthCm']])
plt.figure(2)
plt.boxplot([flower['SepalWidthCm']])
plt.show()

# %%
# Generate the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]])

# %%
# Create a bar chart showing the number of flowers for each species
species_counts = flower['Species'].value_counts()
species_counts.plot(kind='bar')
plt.title("Number of Flowers belonging to the respective species")
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
sepal_lengths = flower['SepalLengthCm'].value_counts()
sepal_widths = flower['SepalWidthCm'].value_counts()

# Create a bar chart for sepal lengths
plt.figure(figsize=(10, 5))
sepal_lengths.plot(kind='bar')
plt.title('Sepal Length Distribution')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
plt.show()

# Create a bar chart for sepal widths
plt.figure(figsize=(10, 5))
sepal_widths.plot(kind='bar')
plt.title('Sepal Width Distribution')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Count')
plt.show()
